# %% [markdown]
# # 作業1：請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：

# %% [markdown]
# 資料：Chicago Crime https://www.kaggle.com/chicago/chicago-crime
#
# 1. 你選的這組資料為何重要
#
# A: 犯罪時間、型態與區域預測
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# A: 提供者為 city of Chicago，以 CC0: Public Domain 的方式分享
# 利用 BigQuery 取得資料
#
# 3. 蒐集而來的資料型態為何
#
# A: 結構化的數值表格，欄位為數值、字串、布林、時間戳記。
#
# 4. 這組資料想解決的問題如何評估
#
# A: 以正確率評估

# %% [markdown]
# # 作業2：想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：

# %% [markdown]
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# A: 以「增加收入」為提升業績的 KPI
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# A: 每台車的載客時間、地點、載客數、性別、語言、接單至到達時間、載客距離、載客路線、每單收入。
# 資料可由後台取得。
#
# 3. 蒐集而來的資料型態為何
#
# A: 為結構化的表格資料。
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
# A: 預測大約什麼時間，什麼地點，哪裡會有客源，並且每單收入是高的。或許可以用期望值做評估，也就是每個區域的載客預期收入；可以增加載客機會，並且減少車輛空繞所造成的成本損失與空氣污染。

# %% [markdown]
# # 作業3：

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(a, b):
    return np.square(a-b).sum()/len(a)

def mean_absolute_error(a, b):
#     print abs(a-b).sum()/len(a)
    return np.fabs(a-b).sum()/len(a)

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 182.631
# The Mean absolute error is 11.024
