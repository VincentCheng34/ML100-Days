# %% [markdown]
# # 9.1 matplotlib API 概觀
#
# * referernce: Python資料分析, O'REILLY

# %%
# %matplotlib notebook or %matplotlib inline
# %matplotlib inline => 不需每次執行 plt.show()
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.arange(10)
plt.plot(data)

# %% [markdown]
# # 圖與子圖

# %%
fig = plt.figure()

ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)

ax1.hist(np.random.randn(100), bins=20, color='k', alpha=0.3)
ax2.scatter(np.arange(30), np.arange(30)+3*np.random.randn(30))
ax3.plot(np.random.randn(50).cumsum(), 'k--')

# %% [markdown]
# # 陣列索引子圖

# %%
# axes = plt.subplots(2, 3)
fig, axes = plt.subplots(2, 3)

axes[0, 1].plot(np.random.randn(50).cumsum(), 'k--')

# %% [markdown]
# # 調整子圖間留白

# %%
# subplots_adjust(wspace=0, hspace=0)
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(np.random.randn(500), bins=50, color='k', alpha=0.5)
plt.subplots_adjust(wspace=0, hspace=0)

# %% [markdown]
# # 色彩、標示和線條樣式

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img1 = mpimg.imread('imgs/Screen Shot 2018-12-01 at 01.15.18.png')
img2 = mpimg.imread('imgs/Screen Shot 2018-12-01 at 01.18.09.png')
img3 = mpimg.imread('imgs/Screen Shot 2018-12-01 at 01.18.14.png')

plt.figure(figsize=(15, 8))
plt.imshow(img1)
plt.show()

plt.figure(figsize=(15, 8))
plt.imshow(img2)
plt.show()

plt.figure(figsize=(15, 8))
plt.imshow(img3)
plt.show()

# %%
fig, axes = plt.subplots(2, 2)

axes[0, 0].plot(np.random.randn(50).cumsum(), 'ro-')
axes[0, 1].plot(np.random.randn(50).cumsum(), 'g^--')
axes[1, 0].plot(np.random.randn(50).cumsum(), 'b>-.')
axes[1, 1].plot(np.random.randn(50).cumsum(), 'yx:')

# %% [markdown]
# # 一個圖形多條線、圖例

# %%
fig, axes = plt.subplots(1, 1)

data = np.random.randn(30).cumsum()
axes.plot(data, 'k--', label='Default')
axes.plot(data, 'g-', drawstyle='steps-post', label='steps-post')

# 圖例
# 不要圖例 label='_nolegend_'
plt.legend(loc='best')

# %% [markdown]
# # 刻度、標籤和圖例
# plt.xlim(), plt.xticks(), plt.xticklabels()

# %%
fig, axes = plt.subplots(1, 2)

data = np.random.randn(30).cumsum()
axes[0].plot(data, 'k--', label='Default')
axes[0].plot(data, 'g-', drawstyle='steps-post', label='steps-post')

axes[1].plot(data, 'k--', label='Default')
axes[1].plot(data, 'g-', drawstyle='steps-post', label='steps-post')

# 設定圖片邊界
plt.ylim([-9, 3])
plt.xlim([-0.5, 10])
# Out:
# (-0.5, 10)

# %% [markdown]
# # 設定主題、軸標籤、刻度和刻度標籤

# %%
fig, axes = plt.subplots(3, 1)

data = np.random.randn(1000).cumsum()

### Pic1
axes[0].plot(data, label='Default')

### Pic2
axes[1].plot(data, label='Default')
# x 刻度標示
axes[1].set_xticks([0, 250, 500, 750, 1000])

### Pic3
axes[2].plot(data, label='Default')
axes[2].set_xticks([0, 250, 500, 750, 1000])
# x 刻度標示
labels = axes[2].set_xticklabels(['one', 'two', 'three', 'four', 'five'], rotation=30, fontsize='small')
# 設定主題
axes[2].set_title('This is the title')
# x 刻度標籤
axes[2].set_xlabel('Times')
# 圖例
axes[2].legend(loc='best')

# 子畫面間的距離
plt.subplots_adjust(wspace=0, hspace=1)

# %% [markdown]
# # 注釋

# %%
a = np.arange(0.0,5.0,0.02)
plt.plot(a,np.cos(2*np.pi*a),'r--')
plt.xlabel('Amplitude', fontsize=20, color = 'green')
plt.ylabel('Time', fontsize=20)

# 注釋
plt.annotate(r'$\mu=100$',xy=(2,1),xytext=(3,1.5),
    arrowprops=dict(facecolor='black',shrink=0.1,width=2))

# 網格
plt.grid()

# %% [markdown]
# # 圖形、存檔

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

rect = plt.Rectangle((0.2, 0.75), 0.4, 0.15, color='r', alpha=0.3)
circ = plt.Circle((0.7, 0.2), 0.15, color='g', alpha=0.3)
pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.26, 0.6]], color='b', alpha=0.5)

# 加入圖形
ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)

# fname: svg, png, pdf, ps, eps...
# dpi: 預設 100
# bbox_inches: 圖的哪個部份要存檔，'tight': 把圖周圍的空白拿掉
# facecolor: 子圖之外的圖背景色，預設 'w' (white)
# edgecolor
# format: svg, png, pdf, ps, eps...
plt.savefig('pic.png', dpi=400, bbox_inches='tight')

# 存到物件
# from io import BytesIO
# buffer = BytesIO()
# plt.savefig(buffer)
# plot_data = buffer.getvalue()

# %% [markdown]
# # matplotlib 設定

# %%
# 改變圖形大小，設為 10x10
# plt.rc('figure', figsize=(10, 10))

# %% [markdown]
# # 其他類型的圖

# %%
# 普通圖
from pylab import *

n = 256
X = np.linspace(-np.pi,np.pi,n,endpoint=True)
Y = np.sin(2*X)

plot (X, Y+1, color='blue', alpha=1.00)
plot (X, Y-1, color='blue', alpha=1.00)

# %%
# 散點圖
from pylab import *

n = 1024
X = np.random.normal(0,1,n)
Y = np.random.normal(0,1,n)

scatter(X,Y)
show()

# %%
# 條形圖
from pylab import *

n = 12
X = np.arange(n)
Y1 = (1-X/float(n)) * np.random.uniform(0.5,1.0,n)
Y2 = (1-X/float(n)) * np.random.uniform(0.5,1.0,n)

bar(X, +Y1, facecolor='#9999ff', edgecolor='white')
bar(X, -Y2, facecolor='#ff9999', edgecolor='white')

for x,y in zip(X,Y1):
    text(x+0.4, y+0.05, '%.2f' % y, ha='center', va= 'bottom')

ylim(-1.25,+1.25)
# Out:
# (-1.25, 1.25)

# %%
# 等高線圖
from pylab import *

def f(x,y): return (1-x/2+x**5+y**3)*np.exp(-x**2-y**2)

n = 256
x = np.linspace(-3,3,n)
y = np.linspace(-3,3,n)
X,Y = np.meshgrid(x,y)

contourf(X, Y, f(X,Y), 8, alpha=.75, cmap='jet')
C = contour(X, Y, f(X,Y), 8, colors='black', linewidth=.5)
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/contour.py:1004: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   s)

# %%
# 灰度圖（Imshow
from pylab import *

def f(x,y): return (1-x/2+x**5+y**3)*np.exp(-x**2-y**2)

n = 10
x = np.linspace(-3,3,4*n)
y = np.linspace(-3,3,3*n)
X,Y = np.meshgrid(x,y)
imshow(f(X,Y))

# %%
# 餅狀圖
from pylab import *

n = 20
Z = np.random.uniform(0,1,n)
piePics = pie(Z)

# %%
# 量場圖（Quiver Plots）
from pylab import *

n = 8
X,Y = np.mgrid[0:n,0:n]
quiver(X,Y)

# %%
# 網格
# from pylab import *

# axes = gca()
# axes.set_xlim(0,4)
# axes.set_ylim(0,3)
# axes.set_xticklabels([])
# axes.set_yticklabels([])

# %%
# 多重網格
# from pylab import *

# subplot(2,2,1)
# subplot(2,2,3)
# subplot(2,2,4)

# %%
# 極軸圖
# from pylab import *

# axes([0,0,1,1])

# N = 20
# theta = np.arange(0.0, 2*np.pi, 2*np.pi/N)
# radii = 10*np.random.rand(N)
# width = np.pi/4*np.random.rand(N)
# bars = bar(theta, radii, width=width, bottom=0.0)

# for r,bar in zip(radii, bars):
#     bar.set_facecolor( cm.jet(r/10.))
#     bar.set_alpha(0.5)

# %%
# 3D 圖
from pylab import *
from mpl_toolkits.mplot3d import Axes3D

fig = figure()
ax = Axes3D(fig)
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='hot')

# %% [markdown]
# # Resouces:
# http://bigsec.net/b52/scipydoc/matplotlib_intro.html
#
# matplotlib gallery
# https://matplotlib.org/2.1.1/gallery/index.html
#
# https://hk.saowen.com/a/2871df0e853f0afa68d0a2923940bd08acd3b38624de30ff05e9c21ee7cb6ec1
#
# https://matplotlib.org/api/markers_api.html
#
# https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html
